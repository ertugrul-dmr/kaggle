# %% [markdown]
# # Introduction
#
# When I started doing this analysis my main goal was getting experience. I'm still learning and trying to improve my skills, so there might be some areas can be improved. My main objectives on this project are:
# * **Explorating and visualising the data with pandas and seaborn packages**
# * **Building and tuning couple regression models to get some stable results with sklearn and xgboost packages**
#
# ## Data Set Information:
#
# This dataset is a slightly modified version of the dataset provided in the StatLib library. In line with the use by Ross Quinlan (1993) in predicting the attribute "mpg", 8 of the original instances were removed because they had unknown values for the "mpg" attribute. The original dataset is available in the file "auto-mpg.data-original".
#
# "The data concerns city-cycle fuel consumption in miles per gallon, to be predicted in terms of 3 multivalued discrete and 5 continuous attributes." (Quinlan, 1993)
#
#
# ## Attribute Information:
#
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
# 9. car name: string (unique for each instance)

# %% [markdown]
# **So let's begin with importing neccesary libraries:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#

from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
train_df = pd.read_csv('auto-mpg.csv')

# %% [markdown]
# ### Exploratory Data Analysis
#
# **Exploratory data analysis would be a great start for us. We need to get some insights before building our models.**

# %%
print(f'Training Shape: {train_df.shape}')
# Out:
# Training Shape: (398, 9)

# %%
print(train_df.head())
print(train_df.sample(5))
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 184  25.0          4         140.0         92    2572          14.9
# 397  31.0          4         119.0         82    2720          19.4
# 231  15.5          8         400.0        190    4325          12.2
# 11   14.0          8         340.0        160    3609           8.0
# 51   30.0          4          79.0         70    2074          19.5
#
#      model year  origin            car name
# 184          76       1            capri ii
# 397          82       1          chevy s-10
# 231          77       1    chrysler cordoba
# 11           70       1  plymouth 'cuda 340
# 51           71       2         peugeot 304

# %%
display(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB
# None

# %% [markdown]
# **When we take a look at basic statistics we can already see that horsepower column has datatype of object but it should be a float type. In order to convert this column first we need to replace missing value "?" in this data to "NaN".**

# %%
train_df['horsepower'] = train_df['horsepower'].replace('?', np.NaN).astype('float64')

# %% [markdown]
# **Before we replace missing values in horsepower let's check correlations between hp and other variables:**

# %%
train_df_corr = train_df.corr().abs().unstack().sort_values(kind='quicksort', ascending=False).reset_index()
train_df_corr.rename(columns={"level_0": "Feature A", 
                             "level_1": "Feature B", 0: 'Correlation Coefficient'}, inplace=True)
train_df_corr[train_df_corr['Feature A'] == 'horsepower'].style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row1_col2 {
#             background-color:  #2d9666;
#             color:  #000000;
#         }    #T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row2_col2 {
#             background-color:  #3b9d66;
#             color:  #000000;
#         }    #T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row3_col2 {
#             background-color:  #44a266;
#             color:  #000000;
#         }    #T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row4_col2 {
#             background-color:  #61b066;
#             color:  #000000;
#         }    #T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row5_col2 {
#             background-color:  #88c366;
#             color:  #000000;
#         }    #T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row6_col2 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row7_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature A</th>        <th class="col_heading level0 col1" >Feature B</th>        <th class="col_heading level0 col2" >Correlation Coefficient</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891level0_row0" class="row_heading level0 row0" >4</th>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row0_col0" class="data row0 col0" >horsepower</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row0_col1" class="data row0 col1" >horsepower</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row0_col2" class="data row0 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891level0_row1" class="row_heading level0 row1" >12</th>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row1_col0" class="data row1 col0" >horsepower</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row1_col1" class="data row1 col1" >displacement</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row1_col2" class="data row1 col2" >0.897257</td>
#             </tr>
#             <tr>
#                         <th id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891level0_row2" class="row_heading level0 row2" >16</th>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row2_col0" class="data row2 col0" >horsepower</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row2_col1" class="data row2 col1" >weight</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row2_col2" class="data row2 col2" >0.864538</td>
#             </tr>
#             <tr>
#                         <th id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891level0_row3" class="row_heading level0 row3" >19</th>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row3_col0" class="data row3 col0" >horsepower</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row3_col1" class="data row3 col1" >cylinders</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row3_col2" class="data row3 col2" >0.842983</td>
#             </tr>
#             <tr>
#                         <th id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891level0_row4" class="row_heading level0 row4" >25</th>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row4_col0" class="data row4 col0" >horsepower</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row4_col1" class="data row4 col1" >mpg</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row4_col2" class="data row4 col2" >0.778427</td>
#             </tr>
#             <tr>
#                         <th id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891level0_row5" class="row_heading level0 row5" >28</th>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row5_col0" class="data row5 col0" >horsepower</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row5_col1" class="data row5 col1" >acceleration</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row5_col2" class="data row5 col2" >0.689196</td>
#             </tr>
#             <tr>
#                         <th id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891level0_row6" class="row_heading level0 row6" >45</th>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row6_col0" class="data row6 col0" >horsepower</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row6_col1" class="data row6 col1" >origin</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row6_col2" class="data row6 col2" >0.455171</td>
#             </tr>
#             <tr>
#                         <th id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891level0_row7" class="row_heading level0 row7" >50</th>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row7_col0" class="data row7 col0" >horsepower</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row7_col1" class="data row7 col1" >model year</td>
#                         <td id="T_6a59e2a6_85cd_11ea_a49d_7824af8ac891row7_col2" class="data row7 col2" >0.416361</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **We are going to fill missing values with grouping more related columns.**

# %%
train_df['horsepower'] = train_df.groupby(['displacement'], sort=False)['horsepower'].apply(lambda x: x.fillna(x.mean()))
train_df['horsepower'] = train_df.groupby(['cylinders'], sort=False)['horsepower'].apply(lambda x: x.fillna(x.mean()))

# %% [markdown]
# **Seems better. Distribution is skewed but we'll deal with it later...**

# %%
sns.set()
plt.subplots(figsize=(10, 6))
sns.distplot(train_df['horsepower'],bins=25)
plt.show()

# %%
print(f'There are some missing values: {train_df.isna().any().any()}')
# Out:
# There are some missing values: False

# %% [markdown]
# **When we look at figure below we notice there is some degree of relation between some of the features by just looking it. Interesting...**

# %%
g = sns.PairGrid(train_df.drop('car name',axis=1), hue='origin')
g = g.map_diag(plt.hist, alpha=0.4)
#g = g.map_offdiag(sns.regplot)
g = g.map_upper(sns.scatterplot)
g = g.map_lower(sns.regplot)

# %% [markdown]
# * **Before we move on, I just wanted to take look at effect of origin on the vehicles mpg since our database is mostly US(Around 62%):**

# %%
org=train_df.copy()
org['origin']=train_df.origin.map({1: 'US', 2: 'Asian',3:'European'})
org['origin'].value_counts(normalize=True)
# Out:
# US          0.625628
# European    0.198492
# Asian       0.175879
# Name: origin, dtype: float64

# %% [markdown]
# **From this boxplot we can easily see that US manufactured cars are least efficent in terms of mpg and they are almost below global average. It might mean nothing though, we need to move on:**

# %%
sns.set()
fig, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='origin', y="mpg", data=org)
plt.axhline(org.mpg.mean(),color='r',linestyle='dashed',linewidth=2)
plt.show()

# %% [markdown]
# **Our heatmap confirms there is some kind of linear relation between these features. Let's see if we can catch this trend with our regression models. We'll be there soon...**

# %%
plt.figure(figsize=(12,6))
sns.heatmap(train_df.corr(),annot=True, linewidths=0.2,cmap='coolwarm', center=0)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %% [markdown]
# ## Data Processing & Feature Engineering

# %% [markdown]
# **Before we move on to build our regression models we might take something out of car names feature instead of just dropping them.**

# %% [markdown]
# * **It looks like our database has the car brands in first words of our car name column, can we extract this out for searching relations between them?**

# %%
pd.crosstab(train_df['car name'],train_df['origin'])
# Out:
# origin                   1  2  3
# car name
# amc ambassador brougham  1  0  0
# amc ambassador dpl       1  0  0
# amc ambassador sst       1  0  0
# amc concord              2  0  0
# amc concord d/l          1  0  0
# ...                     .. .. ..
# vw dasher (diesel)       0  1  0
# vw pickup                0  1  0
# vw rabbit                0  2  0
# vw rabbit c (diesel)     0  1  0
# vw rabbit custom         0  1  0
#
# [305 rows x 3 columns]

# %%
train_df['Brand'] = train_df['car name'].str.extract('([A-Za-z]+)\s', expand=False)

# %% [markdown]
# **Our dataset has some typos and duplicate names for some brands, we must replace them before we proceed.**

# %%
train_df['Brand']= train_df['Brand'].replace(np.NaN, 'subaru')
train_df['Brand']= train_df['Brand'].replace('chevroelt', 'chevrolet')
train_df['Brand']= train_df['Brand'].replace('vw', 'volkswagen')
train_df['Brand']= train_df['Brand'].replace('toyouta', 'toyota')
train_df['Brand']= train_df['Brand'].replace('vokswagen', 'volkswagen')
train_df['Brand']= train_df['Brand'].replace('maxda', 'mazda')
train_df['Brand']= train_df['Brand'].replace('mazada', 'mazda')
train_df['Brand']= train_df['Brand'].replace('chevy', 'chevrolet')

# %%
train_df['Brand'].value_counts(normalize=True)
# Out:
# ford          0.128141
# chevrolet     0.118090
# plymouth      0.077889
# dodge         0.070352
# amc           0.070352
# toyota        0.065327
# datsun        0.057789
# volkswagen    0.055276
# buick         0.042714
# pontiac       0.040201
# honda         0.032663
# mazda         0.030151
# mercury       0.027638
# oldsmobile    0.025126
# fiat          0.020101
# peugeot       0.020101
# audi          0.017588
# chrysler      0.015075
# volvo         0.015075
# renault       0.012563
# subaru        0.010050
# opel          0.010050
# saab          0.010050
# bmw           0.005025
# cadillac      0.005025
# benz          0.005025
# triumph       0.002513
# hi            0.002513
# nissan        0.002513
# capri         0.002513
# mercedes      0.002513
# Name: Brand, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16, 8))
sns.countplot(train_df['Brand'])
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# **It looks much better! It's time to transform these brands to model applicable. We going to categorize them by using sklearn's Label Encoder:**

# %%
le = LabelEncoder()
train_df['Brand'] = le.fit_transform(train_df['Brand'])
train_df.drop('car name', axis=1, inplace=True)
train_df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 168  23.0          4         140.0        83.0    2639          17.0
# 70   13.0          8         400.0       190.0    4422          12.5
# 189  15.5          8         304.0       120.0    3962          13.9
# 95   12.0          8         455.0       225.0    4951          11.0
# 234  24.5          4         151.0        88.0    2740          16.0
#
#      model year  origin  Brand
# 168          75       1     12
# 70           72       1      8
# 189          76       1      0
# 95           73       1      4
# 234          77       1     23

# %% [markdown]
# **Before building our models last thing I want to check is if our data distribution skewed.**

# %%
features=train_df.columns.tolist()
for feature in features:
    print(f'{feature} Skewness: {train_df[feature].skew():.2f}, Kurtosis: {train_df[feature].kurtosis():.2f}')
# Out:
# mpg Skewness: 0.46, Kurtosis: -0.51
# cylinders Skewness: 0.53, Kurtosis: -1.38
# displacement Skewness: 0.72, Kurtosis: -0.75
# horsepower Skewness: 1.11, Kurtosis: 0.75
# weight Skewness: 0.53, Kurtosis: -0.79
# acceleration Skewness: 0.28, Kurtosis: 0.42
# model year Skewness: 0.01, Kurtosis: -1.18
# origin Skewness: 0.92, Kurtosis: -0.82
# Brand Skewness: 0.22, Kurtosis: -1.03

# %% [markdown]
# **Can we decrease our skewness with some log scaling? Well little bit better than before.**

# %%
skew_cols=['cylinders','displacement','horsepower','weight']
train_df[skew_cols]=np.log1p(train_df[skew_cols])
for feature in features:
    print(f'{feature} skewness: {train_df[feature].skew():.2f}, Kurtosis: {train_df[feature].kurtosis():.2f}')
# Out:
# mpg skewness: 0.46, Kurtosis: -0.51
# cylinders skewness: 0.39, Kurtosis: -1.50
# displacement skewness: 0.23, Kurtosis: -1.34
# horsepower skewness: 0.40, Kurtosis: -0.40
# weight skewness: 0.16, Kurtosis: -1.09
# acceleration skewness: 0.28, Kurtosis: 0.42
# model year skewness: 0.01, Kurtosis: -1.18
# origin skewness: 0.92, Kurtosis: -0.82
# Brand skewness: 0.22, Kurtosis: -1.03

# %% [markdown]
# ## Modelling

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, BaggingRegressor
import xgboost as xgb
import lightgbm as lgb

# %% [markdown]
#  **Let's start with cross validation, then we take a closer look on these models**

# %%
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train_df.drop('mpg', axis=1))
    rmse= np.sqrt(np.abs(cross_val_score(model, train_df.drop('mpg', axis=1).values, train_df['mpg'], scoring="neg_mean_squared_error", cv = kf, n_jobs=-1)))
    return(rmse)

def rtw_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train_df.drop('mpg', axis=1))
    rtw= cross_val_score(model, train_df.drop('mpg', axis=1).values, train_df['mpg'], scoring="r2", cv = kf, n_jobs=-1)
    return(rtw)

# %% [markdown]
# **Without tuning hyper-paramaters our best option looks like GradientBoostingRegressor, but while in terms of being very close to GBR, XGBRegressor does little bit better on r2 score.**

# %%
mods = [LinearRegression(),Ridge(),GradientBoostingRegressor(),
      RandomForestRegressor(),BaggingRegressor(),
      xgb.XGBRegressor(), lgb.LGBMRegressor()]

model_df = pd.DataFrame({
    'Model': [type(i).__name__ for i in mods],
    'RMSE': [np.mean(rmsle_cv(i)) for i in mods],    
    'Rmse Std': [np.std(rmsle_cv(i)) for i in mods],
    'R2': [np.mean(rtw_cv(i)) for i in mods],
    'R2 Std': [np.std(rmsle_cv(i)) for i in mods]})
display(model_df.sort_values(by='RMSE', ascending=True).reset_index(drop=True).style.background_gradient(cmap='summer_r'))
# Out:
# <style  type="text/css" >
#     #T_76f58efe_85cd_11ea_b45f_7824af8ac891row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row0_col2 {
#             background-color:  #e9f466;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row0_col3 {
#             background-color:  #068266;
#             color:  #f1f1f1;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row0_col4 {
#             background-color:  #badc66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row1_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row2_col1 {
#             background-color:  #eff766;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row2_col2 {
#             background-color:  #76bb66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row2_col3 {
#             background-color:  #1b8d66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row2_col4 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row3_col1 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row3_col2 {
#             background-color:  #3c9e66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row3_col3 {
#             background-color:  #1b8d66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row3_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row4_col1 {
#             background-color:  #c2e066;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row4_col3 {
#             background-color:  #4ea666;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row4_col4 {
#             background-color:  #81c066;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row5_col1 {
#             background-color:  #048266;
#             color:  #f1f1f1;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row5_col2 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row5_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row5_col4 {
#             background-color:  #d4ea66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row6_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row6_col2 {
#             background-color:  #afd766;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row6_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_76f58efe_85cd_11ea_b45f_7824af8ac891row6_col4 {
#             background-color:  #9fcf66;
#             color:  #000000;
#         }</style><table id="T_76f58efe_85cd_11ea_b45f_7824af8ac891" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >RMSE</th>        <th class="col_heading level0 col2" >Rmse Std</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >R2 Std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76f58efe_85cd_11ea_b45f_7824af8ac891level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row0_col0" class="data row0 col0" >GradientBoostingRegressor</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row0_col1" class="data row0 col1" >2.736373</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row0_col2" class="data row0 col2" >0.943153</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row0_col3" class="data row0 col3" >0.776275</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row0_col4" class="data row0 col4" >0.976350</td>
#             </tr>
#             <tr>
#                         <th id="T_76f58efe_85cd_11ea_b45f_7824af8ac891level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row1_col0" class="data row1 col0" >XGBRegressor</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row1_col1" class="data row1 col1" >2.749040</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row1_col2" class="data row1 col2" >0.922898</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row1_col3" class="data row1 col3" >0.780117</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row1_col4" class="data row1 col4" >0.922898</td>
#             </tr>
#             <tr>
#                         <th id="T_76f58efe_85cd_11ea_b45f_7824af8ac891level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row2_col0" class="data row2 col0" >LGBMRegressor</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row2_col1" class="data row2 col1" >2.792823</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row2_col2" class="data row2 col2" >1.048211</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row2_col3" class="data row2 col3" >0.763523</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row2_col4" class="data row2 col4" >1.048211</td>
#             </tr>
#             <tr>
#                         <th id="T_76f58efe_85cd_11ea_b45f_7824af8ac891level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row3_col0" class="data row3 col0" >RandomForestRegressor</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row3_col1" class="data row3 col1" >2.855399</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row3_col2" class="data row3 col2" >1.101211</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row3_col3" class="data row3 col3" >0.763261</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row3_col4" class="data row3 col4" >1.118838</td>
#             </tr>
#             <tr>
#                         <th id="T_76f58efe_85cd_11ea_b45f_7824af8ac891level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row4_col0" class="data row4 col0" >BaggingRegressor</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row4_col1" class="data row4 col1" >2.941780</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row4_col2" class="data row4 col2" >1.156699</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row4_col3" class="data row4 col3" >0.732393</td>
#                         <td id="T_76f58efe_85cd_11ea_b45f_7824af8ac891row4_col4" class="data row4 col4" >1.020098</td>
#             </tr>
#             <tr>

# %% [markdown]
# **I'm also going to do ta train test split to take a closer look on models and check feature importances on different models.**

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df.drop('mpg', axis=1),train_df['mpg'], test_size= 0.33, random_state=42)

# %%
linreg=LinearRegression()
linreg.fit(X_train,y_train)
y_pred=linreg.predict(X_test)

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse)
print(r2_score(y_test, y_pred))
# Out:
# 2.7398884564782837
# 0.8695729435801217

# %%
ridge = Ridge()
ridge.fit(X_train,y_train)
y_pred=ridge.predict(X_test)

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse)
print(r2_score(y_test, y_pred))
# Out:
# 2.754870735982488
# 0.868142639140324

# %%
bag_regressor = BaggingRegressor()
bag_regressor.fit(X_train,y_train)
y_predict = bag_regressor.predict(X_test)
rmse_bgr = np.sqrt(mean_squared_error(y_test,y_predict))

rmse=np.sqrt(mean_squared_error(y_test,y_predict))
print(rmse)
print(r2_score(y_test, y_predict))
# Out:
# 2.8789995895039024
# 0.8559924925288893

# %%
gb_regressor = GradientBoostingRegressor()
gb_regressor.fit(X_train,y_train)
y_predict = gb_regressor.predict(X_test)
rmse_bgr = np.sqrt(mean_squared_error(y_test,y_predict))

rmse=np.sqrt(mean_squared_error(y_test,y_predict))
print(rmse)
print(r2_score(y_test, y_predict))


feature_imp = pd.DataFrame(sorted(zip(gb_regressor.feature_importances_,train_df.drop('mpg', axis=1).columns)), columns=['Value','Feature'])

plt.figure(figsize=(12, 6))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
plt.title('Features')
plt.tight_layout()
plt.show()
# Out:
# 2.547165239461051
# 0.8872760583650421

# %%
rf_regressor = RandomForestRegressor()
rf_regressor.fit(X_train,y_train)
y_predict = rf_regressor.predict(X_test)
rmse_bgr = np.sqrt(mean_squared_error(y_test,y_predict))

rmse=np.sqrt(mean_squared_error(y_test,y_predict))
print(rmse)
print(r2_score(y_test, y_predict))


feature_imp = pd.DataFrame(sorted(zip(rf_regressor.feature_importances_,train_df.drop('mpg', axis=1).columns)), columns=['Value','Feature'])

plt.figure(figsize=(12, 6))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
plt.title('Features')
plt.tight_layout()
plt.show()
# Out:
# 2.4779217938963836
# 0.8933214464535533

# %%
xg_reg=xgb.XGBRegressor(booster='gbtree', objective='reg:squarederror')

xg_reg.fit(X_train,y_train)
xg_y_pred=xg_reg.predict(X_test)
xg_rmse=np.sqrt(mean_squared_error(y_test,xg_y_pred))
print(xg_rmse)
print(r2_score(y_test,xg_y_pred))

feature_imp = pd.DataFrame(sorted(zip(xg_reg.feature_importances_,train_df.drop('mpg', axis=1).columns)), columns=['Value','Feature'])

plt.figure(figsize=(12, 6))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
plt.title('Features')
plt.tight_layout()
plt.show()
# Out:
# 2.6936688321840863
# 0.8739362186124774

# %%
lgb_reg = lgb.LGBMRegressor()

lgb_reg.fit(X_train,y_train)
y_predict=lgb_reg.predict(X_test)
rmse=np.sqrt(mean_squared_error(y_test,y_predict))
print(rmse)
print(r2_score(y_test,y_predict))

feature_imp = pd.DataFrame(sorted(zip(lgb_reg.feature_importances_,train_df.drop('mpg', axis=1).columns)), columns=['Value','Feature'])

plt.figure(figsize=(12, 6))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
plt.title('Features')
plt.tight_layout()
plt.show()
# Out:
# 2.507874838998369
# 0.8907268043088836

# %% [markdown]
# **I could say our model did ok with the small data we have!**
#
# **Thank you for checking out my work! I'm in my early days of this journey, there is lot to learn. Please let me know if I did some mistakes, I'm still trying to improve myself!**
